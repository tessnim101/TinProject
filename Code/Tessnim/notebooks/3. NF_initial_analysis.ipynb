# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "../../../Data/003GNV/NF/003GNV_V01_FC_Schaefer.pkl"

with open(file, "rb") as f:
    data = pickle.load(f)

print(type(data))

data.keys()

for k, v in data.items():
    print(k, type(v))

FC_FD = data["FC_FD"]

for k, v in FC_FD.items():
    print(k, type(v))

FC_FD_Run1_200 = data["FC_FD"]["V01_Run1_200"]
# Out:
# <class 'dict'>
# FC <class 'dict'>
# FC_FD <class 'dict'>
# V01_Run1_100 <class 'numpy.ndarray'>
# V01_Run1_200 <class 'numpy.ndarray'>
# V01_Run1_400 <class 'numpy.ndarray'>
# V01_Run1_800 <class 'numpy.ndarray'>
# V01_Run2_100 <class 'numpy.ndarray'>
# V01_Run2_200 <class 'numpy.ndarray'>
# V01_Run2_400 <class 'numpy.ndarray'>
# V01_Run2_800 <class 'numpy.ndarray'>
# V01_Run3_100 <class 'numpy.ndarray'>
# V01_Run3_200 <class 'numpy.ndarray'>
# V01_Run3_400 <class 'numpy.ndarray'>
# V01_Run3_800 <class 'numpy.ndarray'>
# V01_Run4_100 <class 'numpy.ndarray'>
# V01_Run4_200 <class 'numpy.ndarray'>
# V01_Run4_400 <class 'numpy.ndarray'>
# V01_Run4_800 <class 'numpy.ndarray'>
# V01_Run5_100 <class 'numpy.ndarray'>
# V01_Run5_200 <class 'numpy.ndarray'>
# V01_Run5_400 <class 'numpy.ndarray'>
# V01_Run5_800 <class 'numpy.ndarray'>
# V01_Run6_100 <class 'numpy.ndarray'>
# V01_Run6_200 <class 'numpy.ndarray'>
# V01_Run6_400 <class 'numpy.ndarray'>
# V01_Run6_800 <class 'numpy.ndarray'>
# ...

# %%
utils_file = "../../../Data/003GNV/NF/003GNV_utils.pkl"

with open(utils_file, "rb") as f:
    utils = pickle.load(f)

print(type(utils))

for k, v in utils.items():
    print(k, type(v))

yeo7_info_200_ROIs = utils["yeo7"]["r200"]["yeoROIs"]
# Out:
# <class 'dict'>
# inds_ROI_overlap_th_Schaefer_NF <class 'int'>
# inds_ROIs_overlapping_Schaefer_NF <class 'dict'>
# inds_to_NaN_NF <class 'dict'>
# inds_to_NaN_th <class 'float'>
# is_motionregonly_NF <class 'numpy.ndarray'>
# is_transfer <class 'numpy.ndarray'>
# NF_paradigm_task_frames <class 'numpy.ndarray'>
# NF_paradigm_rest_frames <class 'numpy.ndarray'>
# OOR_voxels_NF <class 'dict'>
# ROIcounts_NF <class 'dict'>
# ROIs_data_NF <class 'dict'>
# subj_ID <class 'str'>
# total_nb_runs_NF <class 'int'>
# total_nb_runs_NF_per_visit <class 'numpy.ndarray'>
# yeo7 <class 'dict'>
# NF_dir <class 'str'>
# skipped_FDs_frames_NF <class 'numpy.ndarray'>
# skipped_nb_FDs_frames_NF <class 'numpy.ndarray'>
